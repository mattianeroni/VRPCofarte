# %%
import util
import pandas as pd

df = pd.read_csv("../benchmarks.csv", delimiter="\t")

# %% [markdown]
# #### Run

# %%
for filename, n_vehicles, max_travel_time in zip(df.file, df.n_vehicles, df["max_tt"]):
    util.build_time_windows(
                            filename = filename,
                            path = '../data/',
                            n_vehicles = n_vehicles,
                            time_window = 2
                            )

# %%
df
# Out:
#                           file  nodes  n_vehicles  avg_edge  stdev_edge  \
# 0     A-n32-k5_input_nodes.txt     32           5        58          27
# 1     A-n38-k5_input_nodes.txt     38           5        50          23
# 2     A-n45-k7_input_nodes.txt     45           7        48          22
# 3     A-n55-k9_input_nodes.txt     55           9        52          24
# 4     A-n60-k9_input_nodes.txt     60           9        52          24
# 5     A-n61-k9_input_nodes.txt     61           9        46          21
# 6     A-n65-k9_input_nodes.txt     65           9        54          25
# 7    A-n80-k10_input_nodes.txt     80          10        50          24
# 8     B-n50-k7_input_nodes.txt     50           7        50          26
# 9     B-n52-k7_input_nodes.txt     52           7        54          30
# 10    B-n57-k9_input_nodes.txt     57           9        44          22
# 11   B-n78-k10_input_nodes.txt     78          10        50          26
# 12    E-n22-k4_input_nodes.txt     22           4        36          18
# 13    E-n30-k3_input_nodes.txt     30           3        55          33
# 14    E-n33-k4_input_nodes.txt     33           4        37          20
# 15    E-n51-k5_input_nodes.txt     51           5        32          15
# 16   E-n76-k10_input_nodes.txt     76          10        33          15
# 17   E-n76-k14_input_nodes.txt     76          14        33          15
# 18    E-n76-k7_input_nodes.txt     76           7        33          15
# 19   F-n135-k7_input_nodes.txt    135           7        49          42
# 20    F-n45-k4_input_nodes.txt     45           4        53          32
# 21    F-n72-k4_input_nodes.txt     72           4        17           9
# 22  M-n101-k10_input_nodes.txt    101          10        39          19
# 23   M-n121-k7_input_nodes.txt    121           7        53          27
# 24   P-n101-k4_input_nodes.txt    101           4        33          16
# 25    P-n22-k8_input_nodes.txt     22           8        36          18
# 26    P-n40-k5_input_nodes.txt     40           5        31          14
# 27   P-n50-k10_input_nodes.txt     50          10        30          14
# 28   P-n55-k15_input_nodes.txt     55          15        30          14
# 29   P-n65-k10_input_nodes.txt     65          10        32          15
# 30   P-n70-k10_input_nodes.txt     70          10        33          15
# 31    P-n76-k4_input_nodes.txt     76           4        33          15
# 32    P-n76-k5_input_nodes.txt     76           5        33          15
#
#     75q_edge  nodes_per_vehicle  avg_tt  max_tt
# 0         76                  7     464     508
# 1         65                  8     450     485
# 2         62                  7     384     396
# 3         68                  7     416     444
# 4         68                  7     416     444
# 5         60                  7     368     380
# 6         70                  8     486     530
# 7         66                  8     450     594
# 8         67                  8     450     603
# 9         74                  8     486     666
# 10        58                  7     352     464
# 11        67                  8     450     603
# 12        48                  6     252     336
# 13        77                 10     605     847
# 14        50                  9     370     500
# 15        42                 11     384     504
# 16        43                  8     297     387
# 17        43                  6     231     301
# 18        43                 11     396     516
# 19        77                 20    1029    1617
# 20        74                 12     689     962
# 21        23                 18     323     437
# 22        51                 11     468     612
# 23        71                 18    1007    1349
# 24        43                 26     891    1161
# 25        48                  3     144     192
# 26        40                  8     279     360
# 27        39                  5     180     234
# 28        39                  4     150     195
# 29        42                  7     256     336
# 30        43                  7     264     344
# 31        43                 19     660     860
# 32        43                 16     561     731
